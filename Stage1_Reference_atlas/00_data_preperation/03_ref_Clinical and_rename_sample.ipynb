# %% [markdown]
# # Reference_Atlas_scRNA

# %% [markdown]
# # Rename SampleID, Run in R env

# %% [markdown]
# ## scRNA

# %%
scRNA_list = basename(list.dirs("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/",recursive = F))
scRNA_list
# Out:
#  [1] "CRS20230712_N1_EmptyDrops_CR_310270_matrix"
#  [2] "CRS20230712_N2_EmptyDrops_CR_310271_matrix"
#  [3] "CRS20230712_N3_EmptyDrops_CR_316857_matrix"
#  [4] "JXP20230714_N1_EmptyDrops_CR_310290_matrix"
#  [5] "JXP20230714_N2_EmptyDrops_CR_312247_matrix"
#  [6] "JXP20230714_N3_EmptyDrops_CR_310294_matrix"
#  [7] "NJY20230714_N1_EmptyDrops_CR_310283_matrix"
#  [8] "NJY20230714_N2_EmptyDrops_CR_310284_matrix"
#  [9] "NJY20230714_N3_EmptyDrops_CR_312245_matrix"
# [10] "SDD20230714_N1_EmptyDrops_CR_310273_matrix"
# [11] "SDD20230714_N2_EmptyDrops_CR_312242_matrix"
# [12] "SDD20230714_N3_EmptyDrops_CR_310275_matrix"
# [13] "TXM20230714_N1_EmptyDrops_CR_312793_matrix"
# [14] "TXM20230714_N2_EmptyDrops_CR_310287_matrix"
# [15] "TXM20230714_N3_EmptyDrops_CR_310289_matrix"
# [16] "WMH20230714_N1_EmptyDrops_CR_310276_matrix"
# [17] "WMH20230714_N2_EmptyDrops_CR_312809_matrix"
# [18] "WMH20230714_N3_EmptyDrops_CR_310279_matrix"
# [19] "ZG20230714_N1_EmptyDrops_CR_310280_matrix"
# ...

# %%
scRNA_list = limma::strsplit2(scRNA_list,'_EmptyDrops_CR_')[,1]
length(scRNA_list)
scRNA_list
# Out:
# [1] 24
#  [1] "CRS20230712_N1" "CRS20230712_N2" "CRS20230712_N3" "JXP20230714_N1"
#  [5] "JXP20230714_N2" "JXP20230714_N3" "NJY20230714_N1" "NJY20230714_N2"
#  [9] "NJY20230714_N3" "SDD20230714_N1" "SDD20230714_N2" "SDD20230714_N3"
# [13] "TXM20230714_N1" "TXM20230714_N2" "TXM20230714_N3" "WMH20230714_N1"
# [17] "WMH20230714_N2" "WMH20230714_N3" "ZG20230714_N1"  "ZG20230714_N2"
# [21] "ZG20230714_N3"  "ZY20230521_N1"  "ZY20230521_N2"  "ZY20230521_N3"

# %% [markdown]
# ## TCR

# %%
TCR_list = basename(list.files("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_TCR_out/",recursive = F))
TCR_list
# Out:
#  [1] "CRS20230712_N1-T_filtered_contig_annotations.csv"
#  [2] "CRS20230712_N2-T_filtered_contig_annotations.csv"
#  [3] "CRS20230712_N3-T_filtered_contig_annotations.csv"
#  [4] "JXP20230714_N1-T_filtered_contig_annotations.csv"
#  [5] "JXP20230714_N2-T_filtered_contig_annotations.csv"
#  [6] "JXP20230714_N3-T_filtered_contig_annotations.csv"
#  [7] "NJY20230714_N1-T_filtered_contig_annotations.csv"
#  [8] "NJY20230714_N2-T_filtered_contig_annotations.csv"
#  [9] "NJY20230714_N3-T_filtered_contig_annotations.csv"
# [10] "SDD20230714_N1-T_filtered_contig_annotations.csv"
# [11] "SDD20230714_N2-T_filtered_contig_annotations.csv"
# [12] "SDD20230714_N3-T_filtered_contig_annotations.csv"
# [13] "TXM20230714_N1-T_filtered_contig_annotations.csv"
# [14] "TXM20230714_N2-T_filtered_contig_annotations.csv"
# [15] "TXM20230714_N3-T_filtered_contig_annotations.csv"
# [16] "WMH20230714_N1-T_filtered_contig_annotations.csv"
# [17] "WMH20230714_N2-T_filtered_contig_annotations.csv"
# ...

# %%
TCR_list = limma::strsplit2(TCR_list,'_filtered_contig_annotations.csv')[,1]
length(TCR_list)
TCR_list
# Out:
# [1] 24
#  [1] "CRS20230712_N1-T" "CRS20230712_N2-T" "CRS20230712_N3-T" "JXP20230714_N1-T"
#  [5] "JXP20230714_N2-T" "JXP20230714_N3-T" "NJY20230714_N1-T" "NJY20230714_N2-T"
#  [9] "NJY20230714_N3-T" "SDD20230714_N1-T" "SDD20230714_N2-T" "SDD20230714_N3-T"
# [13] "TXM20230714_N1-T" "TXM20230714_N2-T" "TXM20230714_N3-T" "WMH20230714_N1-T"
# [17] "WMH20230714_N2-T" "WMH20230714_N3-T" "ZG20230714_N1-T"  "ZG20230714_N2-T"
# [21] "ZG20230714_N3-T"  "ZY20230521_N1-T"  "ZY20230521_N2-T"  "ZY20230521_N3-T"

# %%
TCR_list = gsub('-T','',TCR_list)
TCR_list
# Out:
#  [1] "CRS20230712_N1" "CRS20230712_N2" "CRS20230712_N3" "JXP20230714_N1"
#  [5] "JXP20230714_N2" "JXP20230714_N3" "NJY20230714_N1" "NJY20230714_N2"
#  [9] "NJY20230714_N3" "SDD20230714_N1" "SDD20230714_N2" "SDD20230714_N3"
# [13] "TXM20230714_N1" "TXM20230714_N2" "TXM20230714_N3" "WMH20230714_N1"
# [17] "WMH20230714_N2" "WMH20230714_N3" "ZG20230714_N1"  "ZG20230714_N2"
# [21] "ZG20230714_N3"  "ZY20230521_N1"  "ZY20230521_N2"  "ZY20230521_N3"

# %%
all(TCR_list == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# ## BCR

# %%
BCR_list = basename(list.files("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_BCR_out/",recursive = F))
BCR_list
# Out:
#  [1] "CRS20230712_N1-B_filtered_contig_annotations.csv"
#  [2] "CRS20230712_N2-B_filtered_contig_annotations.csv"
#  [3] "CRS20230712_N3-B_filtered_contig_annotations.csv"
#  [4] "JXP20230714_N1-B_filtered_contig_annotations.csv"
#  [5] "JXP20230714_N2-B_filtered_contig_annotations.csv"
#  [6] "JXP20230714_N3-B_filtered_contig_annotations.csv"
#  [7] "NJY20230714_N1-B_filtered_contig_annotations.csv"
#  [8] "NJY20230714_N2-B_filtered_contig_annotations.csv"
#  [9] "NJY20230714_N3-B_filtered_contig_annotations.csv"
# [10] "SDD20230714_N1-B_filtered_contig_annotations.csv"
# [11] "SDD20230714_N2-B_filtered_contig_annotations.csv"
# [12] "SDD20230714_N3-B_filtered_contig_annotations.csv"
# [13] "TXM20230714_N1-B_filtered_contig_annotations.csv"
# [14] "TXM20230714_N2-B_filtered_contig_annotations.csv"
# [15] "TXM20230714_N3-B_filtered_contig_annotations.csv"
# [16] "WMH20230714_N1-B_filtered_contig_annotations.csv"
# [17] "WMH20230714_N2-B_filtered_contig_annotations.csv"
# ...

# %%
BCR_list = limma::strsplit2(BCR_list,'_filtered_contig_annotations.csv')[,1]
length(BCR_list)
BCR_list
# Out:
# [1] 24
#  [1] "CRS20230712_N1-B" "CRS20230712_N2-B" "CRS20230712_N3-B" "JXP20230714_N1-B"
#  [5] "JXP20230714_N2-B" "JXP20230714_N3-B" "NJY20230714_N1-B" "NJY20230714_N2-B"
#  [9] "NJY20230714_N3-B" "SDD20230714_N1-B" "SDD20230714_N2-B" "SDD20230714_N3-B"
# [13] "TXM20230714_N1-B" "TXM20230714_N2-B" "TXM20230714_N3-B" "WMH20230714_N1-B"
# [17] "WMH20230714_N2-B" "WMH20230714_N3-B" "ZG20230714_N1-B"  "ZG20230714_N2-B"
# [21] "ZG20230714_N3-B"  "ZY20230521_N1-B"  "ZY20230521_N2-B"  "ZY20230521_N3-B"

# %%
BCR_list = gsub('-B','',TCR_list)
BCR_list
# Out:
#  [1] "CRS20230712_N1" "CRS20230712_N2" "CRS20230712_N3" "JXP20230714_N1"
#  [5] "JXP20230714_N2" "JXP20230714_N3" "NJY20230714_N1" "NJY20230714_N2"
#  [9] "NJY20230714_N3" "SDD20230714_N1" "SDD20230714_N2" "SDD20230714_N3"
# [13] "TXM20230714_N1" "TXM20230714_N2" "TXM20230714_N3" "WMH20230714_N1"
# [17] "WMH20230714_N2" "WMH20230714_N3" "ZG20230714_N1"  "ZG20230714_N2"
# [21] "ZG20230714_N3"  "ZY20230521_N1"  "ZY20230521_N2"  "ZY20230521_N3"

# %%
all(BCR_list == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# # rename

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/")

# %%
scRNA_list = basename(list.dirs(".",recursive = F))
scRNA_list
# Out:
#  [1] "CRS20230712_N1_EmptyDrops_CR_310270_matrix"
#  [2] "CRS20230712_N2_EmptyDrops_CR_310271_matrix"
#  [3] "CRS20230712_N3_EmptyDrops_CR_316857_matrix"
#  [4] "JXP20230714_N1_EmptyDrops_CR_310290_matrix"
#  [5] "JXP20230714_N2_EmptyDrops_CR_312247_matrix"
#  [6] "JXP20230714_N3_EmptyDrops_CR_310294_matrix"
#  [7] "NJY20230714_N1_EmptyDrops_CR_310283_matrix"
#  [8] "NJY20230714_N2_EmptyDrops_CR_310284_matrix"
#  [9] "NJY20230714_N3_EmptyDrops_CR_312245_matrix"
# [10] "SDD20230714_N1_EmptyDrops_CR_310273_matrix"
# [11] "SDD20230714_N2_EmptyDrops_CR_312242_matrix"
# [12] "SDD20230714_N3_EmptyDrops_CR_310275_matrix"
# [13] "TXM20230714_N1_EmptyDrops_CR_312793_matrix"
# [14] "TXM20230714_N2_EmptyDrops_CR_310287_matrix"
# [15] "TXM20230714_N3_EmptyDrops_CR_310289_matrix"
# [16] "WMH20230714_N1_EmptyDrops_CR_310276_matrix"
# [17] "WMH20230714_N2_EmptyDrops_CR_312809_matrix"
# [18] "WMH20230714_N3_EmptyDrops_CR_310279_matrix"
# [19] "ZG20230714_N1_EmptyDrops_CR_310280_matrix"
# ...

# %%
rename_list = c('D0001_PBMC','D0001_WB','D0001_Mix',
                'D0002_PBMC','D0002_WB','D0002_Mix',
                'D0003_PBMC','D0003_WB','D0003_Mix',
                'D0004_PBMC','D0004_WB','D0004_Mix',
                'D0005_PBMC','D0005_WB','D0005_Mix',
                'D0006_PBMC','D0006_WB','D0006_Mix',
                'D0007_PBMC','D0007_WB','D0007_Mix',
                'D0008_PBMC','D0008_WB','D0008_Mix')
rename_list
# Out:
#  [1] "D0001_PBMC" "D0001_WB"   "D0001_Mix"  "D0002_PBMC" "D0002_WB"
#  [6] "D0002_Mix"  "D0003_PBMC" "D0003_WB"   "D0003_Mix"  "D0004_PBMC"
# [11] "D0004_WB"   "D0004_Mix"  "D0005_PBMC" "D0005_WB"   "D0005_Mix"
# [16] "D0006_PBMC" "D0006_WB"   "D0006_Mix"  "D0007_PBMC" "D0007_WB"
# [21] "D0007_Mix"  "D0008_PBMC" "D0008_WB"   "D0008_Mix"

# %%
file.rename(from = scRNA_list,
            to = rename_list)
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_TCR_out/")

# %%
TCR_list = basename(list.files('.',recursive = F))
TCR_list
# Out:
#  [1] "CRS20230712_N1-T_filtered_contig_annotations.csv"
#  [2] "CRS20230712_N2-T_filtered_contig_annotations.csv"
#  [3] "CRS20230712_N3-T_filtered_contig_annotations.csv"
#  [4] "JXP20230714_N1-T_filtered_contig_annotations.csv"
#  [5] "JXP20230714_N2-T_filtered_contig_annotations.csv"
#  [6] "JXP20230714_N3-T_filtered_contig_annotations.csv"
#  [7] "NJY20230714_N1-T_filtered_contig_annotations.csv"
#  [8] "NJY20230714_N2-T_filtered_contig_annotations.csv"
#  [9] "NJY20230714_N3-T_filtered_contig_annotations.csv"
# [10] "SDD20230714_N1-T_filtered_contig_annotations.csv"
# [11] "SDD20230714_N2-T_filtered_contig_annotations.csv"
# [12] "SDD20230714_N3-T_filtered_contig_annotations.csv"
# [13] "TXM20230714_N1-T_filtered_contig_annotations.csv"
# [14] "TXM20230714_N2-T_filtered_contig_annotations.csv"
# [15] "TXM20230714_N3-T_filtered_contig_annotations.csv"
# [16] "WMH20230714_N1-T_filtered_contig_annotations.csv"
# [17] "WMH20230714_N2-T_filtered_contig_annotations.csv"
# ...

# %%
rename_list = c('D0001_PBMC.csv','D0001_WB.csv','D0001_Mix.csv',
                'D0002_PBMC.csv','D0002_WB.csv','D0002_Mix.csv',
                'D0003_PBMC.csv','D0003_WB.csv','D0003_Mix.csv',
                'D0004_PBMC.csv','D0004_WB.csv','D0004_Mix.csv',
                'D0005_PBMC.csv','D0005_WB.csv','D0005_Mix.csv',
                'D0006_PBMC.csv','D0006_WB.csv','D0006_Mix.csv',
                'D0007_PBMC.csv','D0007_WB.csv','D0007_Mix.csv',
                'D0008_PBMC.csv','D0008_WB.csv','D0008_Mix.csv')
rename_list
# Out:
#  [1] "D0001_PBMC.csv" "D0001_WB.csv"   "D0001_Mix.csv"  "D0002_PBMC.csv"
#  [5] "D0002_WB.csv"   "D0002_Mix.csv"  "D0003_PBMC.csv" "D0003_WB.csv"
#  [9] "D0003_Mix.csv"  "D0004_PBMC.csv" "D0004_WB.csv"   "D0004_Mix.csv"
# [13] "D0005_PBMC.csv" "D0005_WB.csv"   "D0005_Mix.csv"  "D0006_PBMC.csv"
# [17] "D0006_WB.csv"   "D0006_Mix.csv"  "D0007_PBMC.csv" "D0007_WB.csv"
# [21] "D0007_Mix.csv"  "D0008_PBMC.csv" "D0008_WB.csv"   "D0008_Mix.csv"

# %%
file.rename(from = TCR_list,
            to = rename_list)
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_BCR_out/")

# %%
BCR_list = basename(list.files(".",recursive = F))
BCR_list
# Out:
#  [1] "CRS20230712_N1-B_filtered_contig_annotations.csv"
#  [2] "CRS20230712_N2-B_filtered_contig_annotations.csv"
#  [3] "CRS20230712_N3-B_filtered_contig_annotations.csv"
#  [4] "JXP20230714_N1-B_filtered_contig_annotations.csv"
#  [5] "JXP20230714_N2-B_filtered_contig_annotations.csv"
#  [6] "JXP20230714_N3-B_filtered_contig_annotations.csv"
#  [7] "NJY20230714_N1-B_filtered_contig_annotations.csv"
#  [8] "NJY20230714_N2-B_filtered_contig_annotations.csv"
#  [9] "NJY20230714_N3-B_filtered_contig_annotations.csv"
# [10] "SDD20230714_N1-B_filtered_contig_annotations.csv"
# [11] "SDD20230714_N2-B_filtered_contig_annotations.csv"
# [12] "SDD20230714_N3-B_filtered_contig_annotations.csv"
# [13] "TXM20230714_N1-B_filtered_contig_annotations.csv"
# [14] "TXM20230714_N2-B_filtered_contig_annotations.csv"
# [15] "TXM20230714_N3-B_filtered_contig_annotations.csv"
# [16] "WMH20230714_N1-B_filtered_contig_annotations.csv"
# [17] "WMH20230714_N2-B_filtered_contig_annotations.csv"
# ...

# %%
rename_list = c('D0001_PBMC.csv','D0001_WB.csv','D0001_Mix.csv',
                'D0002_PBMC.csv','D0002_WB.csv','D0002_Mix.csv',
                'D0003_PBMC.csv','D0003_WB.csv','D0003_Mix.csv',
                'D0004_PBMC.csv','D0004_WB.csv','D0004_Mix.csv',
                'D0005_PBMC.csv','D0005_WB.csv','D0005_Mix.csv',
                'D0006_PBMC.csv','D0006_WB.csv','D0006_Mix.csv',
                'D0007_PBMC.csv','D0007_WB.csv','D0007_Mix.csv',
                'D0008_PBMC.csv','D0008_WB.csv','D0008_Mix.csv')
rename_list
# Out:
#  [1] "D0001_PBMC.csv" "D0001_WB.csv"   "D0001_Mix.csv"  "D0002_PBMC.csv"
#  [5] "D0002_WB.csv"   "D0002_Mix.csv"  "D0003_PBMC.csv" "D0003_WB.csv"
#  [9] "D0003_Mix.csv"  "D0004_PBMC.csv" "D0004_WB.csv"   "D0004_Mix.csv"
# [13] "D0005_PBMC.csv" "D0005_WB.csv"   "D0005_Mix.csv"  "D0006_PBMC.csv"
# [17] "D0006_WB.csv"   "D0006_Mix.csv"  "D0007_PBMC.csv" "D0007_WB.csv"
# [21] "D0007_Mix.csv"  "D0008_PBMC.csv" "D0008_WB.csv"   "D0008_Mix.csv"

# %%
file.rename(from = BCR_list,
            to = rename_list)
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
