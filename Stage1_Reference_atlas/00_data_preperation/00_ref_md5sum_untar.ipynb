# %% [markdown]
# # MD5 check in shell

# %% [markdown]
# ## Reference atlas scRNA-seq

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/Reference_Atlas_scRNA

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 24 my_func

# %% [raw]
# All md5sum output is OK!

# %% [markdown]
# ## Reference atlas VDJ

# %%
#run in shell
#TCR
cd /localdisk/immune/0_raw_immune1k/celescope_v2/Reference_Atlas_TCR

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 24 my_func

# %% [raw]
# All md5sum output is OK!

# %%
#run in shell
#BCR
cd /localdisk/immune/0_raw_immune1k/celescope_v2/Reference_Atlas_BCR

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 24 my_func

# %%
All md5sum output is OK!

# %% [markdown]
# ## Reference_Atlas solo out

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/Reference_Atlas_scRNA_solo_out

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 24 my_func

# %%
All md5sum output is OK!

# %% [markdown]
# # Untar

# %% [markdown]
# ## Reference atlas

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/Reference_Atlas_scRNA

for sample in `ls *.tar`
do
mkdir -p /home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/$(basename $sample .tar)
tar -xvf $sample -C /home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/$(basename $sample .tar)
done

# %%
# Run in shell, remove the redundant files generated by emptydrop in celescope v2
rm -rf /home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/*/GeneFull_Ex50pAS/filtered
