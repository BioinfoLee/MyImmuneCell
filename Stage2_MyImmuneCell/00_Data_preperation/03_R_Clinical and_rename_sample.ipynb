# %% [markdown]
# # MyImmuCell

# %%
setwd("/home/liyanguo/MyImmuCell/")

# %% [markdown]
# ## Read info

# %%
rename_data = read.csv("01_rawdata/MyImmuCell_sample_info.csv")

# %%
head(rename_data)
# Out:
#   DonorID SampleID   Batch CITE.seq.RNA.file.name CITE.seq.ADT.file.name
# 1 D0009   D0009_Rep1 B4    BBH202401160012_N-X1   BBH202401160012_N-X1-CUS
# 2 D0009   D0009_Rep2 B4    BBH202401160012_N-X2   BBH202401160012_N-X2-CUS
# 3 D0010   D0010_Rep1 B5    BFG202407199019_N-X1   BFG202407199019_N-X1-CUS
# 4 D0010   D0010_Rep2 B5    BFG202407199019_N-X2   BFG202407199019_N-X2-CUS
# 5 D0011   D0011_Rep1 B6    BL202401170033_N-X1    BL202401170033_N-X1-CUS
# 6 D0011   D0011_Rep2 B6    BL202401170033_N-X2    BL202401170033_N-X2-CUS
#   TCR.file.name          BCR.file.name
# 1 BBH202401160012_N-T-X1 BBH202401160012_N-B-X1
# 2 BBH202401160012_N-T-X2 BBH202401160012_N-B-X2
# 3 BFG202407199019_N-T-X1 BFG202407199019_N-B-X1
# 4 BFG202407199019_N-T-X2 BFG202407199019_N-B-X2
# 5 BL202401170033_N-T-X1  BL202401170033_N-B-X1
# 6 BL202401170033_N-T-X2  BL202401170033_N-B-X2

# %% [markdown]
# ## MyImmuCell scRNA ID

# %%
scRNA_list = basename(list.dirs("01_rawdata/MyImmuCell_scRNA/",recursive = F))
head(scRNA_list)
length(scRNA_list)
# Out:
# [1] "BBH202401160012_N-X1_EmptyDrops_CR_310414_matrix"
# [2] "BBH202401160012_N-X2_EmptyDrops_CR_308207_matrix"
# [3] "BFG202407199019_N-X1_EmptyDrops_CR_310929_matrix"
# [4] "BFG202407199019_N-X2_EmptyDrops_CR_310925_matrix"
# [5] "BL202401170033_N-X1_EmptyDrops_CR_308242_matrix"
# [6] "BL202401170033_N-X2_EmptyDrops_CR_308243_matrix"
# [1] 1998

# %%
scRNA_list = limma::strsplit2(scRNA_list,'_EmptyDrops_CR_')[,1]
head(scRNA_list)
length(scRNA_list)
# Out:
# [1] "BBH202401160012_N-X1" "BBH202401160012_N-X2" "BFG202407199019_N-X1"
# [4] "BFG202407199019_N-X2" "BL202401170033_N-X1"  "BL202401170033_N-X2"
# [1] 1998

# %%
all(rename_data$CITE.seq.RNA.file.name == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# ## MyImmuCell ADT ID

# %%
ADT_list = basename(list.files("01_rawdata/MyImmuCell_ADT/",recursive = F))
head(ADT_list)
length(ADT_list)
# Out:
# [1] "BBH202401160012_N-X1-CUS_EmptyDrops_CR_313661_matrix.csv"
# [2] "BBH202401160012_N-X2-CUS_EmptyDrops_CR_313657_matrix.csv"
# [3] "BFG202407199019_N-X1-CUS_EmptyDrops_CR_315130_matrix.csv"
# [4] "BFG202407199019_N-X2-CUS_EmptyDrops_CR_315155_matrix.csv"
# [5] "BL202401170033_N-X1-CUS_EmptyDrops_CR_313059_matrix.csv"
# [6] "BL202401170033_N-X2-CUS_EmptyDrops_CR_313063_matrix.csv"
# [1] 1998

# %%
ADT_list = limma::strsplit2(ADT_list,'_EmptyDrops_CR_')[,1]
head(ADT_list)
length(ADT_list)
# Out:
# [1] "BBH202401160012_N-X1-CUS" "BBH202401160012_N-X2-CUS"
# [3] "BFG202407199019_N-X1-CUS" "BFG202407199019_N-X2-CUS"
# [5] "BL202401170033_N-X1-CUS"  "BL202401170033_N-X2-CUS"
# [1] 1998

# %%
all(rename_data$CITE.seq.ADT.file.name == ADT_list)
# Out:
# [1] TRUE

# %%
ADT_list = gsub('_TAG-CUS','',ADT_list)

# %%
ADT_list = gsub('-CUS','',ADT_list)

# %%
head(ADT_list)
# Out:
# [1] "BBH202401160012_N-X1" "BBH202401160012_N-X2" "BFG202407199019_N-X1"
# [4] "BFG202407199019_N-X2" "BL202401170033_N-X1"  "BL202401170033_N-X2"

# %%
all(ADT_list == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# ## MyImmuCell TCR ID

# %%
TCR_list = basename(list.files("01_rawdata/MyImmuCell_TCR_out/",recursive = F))
head(TCR_list)
# Out:
# [1] "BBH202401160012_N-T-X1_filtered_contig_annotations.csv"
# [2] "BBH202401160012_N-T-X2_filtered_contig_annotations.csv"
# [3] "BFG202407199019_N-T-X1_filtered_contig_annotations.csv"
# [4] "BFG202407199019_N-T-X2_filtered_contig_annotations.csv"
# [5] "BL202401170033_N-T-X1_filtered_contig_annotations.csv"
# [6] "BL202401170033_N-T-X2_filtered_contig_annotations.csv"

# %%
TCR_list = limma::strsplit2(TCR_list,'_filtered_contig_annotations.csv')[,1]
head(TCR_list)
length(TCR_list)
# Out:
# [1] "BBH202401160012_N-T-X1" "BBH202401160012_N-T-X2" "BFG202407199019_N-T-X1"
# [4] "BFG202407199019_N-T-X2" "BL202401170033_N-T-X1"  "BL202401170033_N-T-X2"
# [1] 1998

# %%
all(rename_data$TCR.file.name == TCR_list)
# Out:
# [1] TRUE

# %%
TCR_list = gsub('-T-','-',TCR_list)
head(TCR_list)
# Out:
# [1] "BBH202401160012_N-X1" "BBH202401160012_N-X2" "BFG202407199019_N-X1"
# [4] "BFG202407199019_N-X2" "BL202401170033_N-X1"  "BL202401170033_N-X2"

# %%
all(TCR_list == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# ## MyImmuCell BCR ID

# %%
BCR_list = basename(list.files("01_rawdata/MyImmuCell_BCR_out/",recursive = F))
head(BCR_list)
# Out:
# [1] "BBH202401160012_N-B-X1_filtered_contig_annotations.csv"
# [2] "BBH202401160012_N-B-X2_filtered_contig_annotations.csv"
# [3] "BFG202407199019_N-B-X1_filtered_contig_annotations.csv"
# [4] "BFG202407199019_N-B-X2_filtered_contig_annotations.csv"
# [5] "BL202401170033_N-B-X1_filtered_contig_annotations.csv"
# [6] "BL202401170033_N-B-X2_filtered_contig_annotations.csv"

# %%
BCR_list = limma::strsplit2(BCR_list,'_filtered_contig_annotations.csv')[,1]
head(BCR_list)
length(BCR_list)
# Out:
# [1] "BBH202401160012_N-B-X1" "BBH202401160012_N-B-X2" "BFG202407199019_N-B-X1"
# [4] "BFG202407199019_N-B-X2" "BL202401170033_N-B-X1"  "BL202401170033_N-B-X2"
# [1] 1998

# %%
all(rename_data$BCR.file.name == BCR_list)
# Out:
# [1] TRUE

# %%
BCR_list = gsub('-B-','-',BCR_list)
head(TCR_list)
# Out:
# [1] "BBH202401160012_N-X1" "BBH202401160012_N-X2" "BFG202407199019_N-X1"
# [4] "BFG202407199019_N-X2" "BL202401170033_N-X1"  "BL202401170033_N-X2"

# %%
all(BCR_list == scRNA_list)
# Out:
# [1] TRUE

# %% [markdown]
# # Rename SampleID

# %%
head(rename_data)
# Out:
#   DonorID SampleID   Batch CITE.seq.RNA.file.name CITE.seq.ADT.file.name
# 1 D0009   D0009_Rep1 B4    BBH202401160012_N-X1   BBH202401160012_N-X1-CUS
# 2 D0009   D0009_Rep2 B4    BBH202401160012_N-X2   BBH202401160012_N-X2-CUS
# 3 D0010   D0010_Rep1 B5    BFG202407199019_N-X1   BFG202407199019_N-X1-CUS
# 4 D0010   D0010_Rep2 B5    BFG202407199019_N-X2   BFG202407199019_N-X2-CUS
# 5 D0011   D0011_Rep1 B6    BL202401170033_N-X1    BL202401170033_N-X1-CUS
# 6 D0011   D0011_Rep2 B6    BL202401170033_N-X2    BL202401170033_N-X2-CUS
#   TCR.file.name          BCR.file.name
# 1 BBH202401160012_N-T-X1 BBH202401160012_N-B-X1
# 2 BBH202401160012_N-T-X2 BBH202401160012_N-B-X2
# 3 BFG202407199019_N-T-X1 BFG202407199019_N-B-X1
# 4 BFG202407199019_N-T-X2 BFG202407199019_N-B-X2
# 5 BL202401170033_N-T-X1  BL202401170033_N-B-X1
# 6 BL202401170033_N-T-X2  BL202401170033_N-B-X2

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_scRNA/")

# %%
scRNA_list = basename(list.dirs(".",recursive = F,full.names = TRUE))
head(scRNA_list)
# Out:
# [1] "BBH202401160012_N-X1_EmptyDrops_CR_310414_matrix"
# [2] "BBH202401160012_N-X2_EmptyDrops_CR_308207_matrix"
# [3] "BFG202407199019_N-X1_EmptyDrops_CR_310929_matrix"
# [4] "BFG202407199019_N-X2_EmptyDrops_CR_310925_matrix"
# [5] "BL202401170033_N-X1_EmptyDrops_CR_308242_matrix"
# [6] "BL202401170033_N-X2_EmptyDrops_CR_308243_matrix"

# %%
file.rename(from = scRNA_list,
            to = rename_data$SampleID)
# Out:
#    [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [15] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [29] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [43] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [57] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [71] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [85] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [99] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [113] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [127] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [141] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [155] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# ...

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_ADT/")

# %%
ADT_list = basename(list.files(".",recursive = F))
head(ADT_list)
length(ADT_list)
# Out:
# [1] "BBH202401160012_N-X1-CUS_EmptyDrops_CR_313661_matrix.csv"
# [2] "BBH202401160012_N-X2-CUS_EmptyDrops_CR_313657_matrix.csv"
# [3] "BFG202407199019_N-X1-CUS_EmptyDrops_CR_315130_matrix.csv"
# [4] "BFG202407199019_N-X2-CUS_EmptyDrops_CR_315155_matrix.csv"
# [5] "BL202401170033_N-X1-CUS_EmptyDrops_CR_313059_matrix.csv"
# [6] "BL202401170033_N-X2-CUS_EmptyDrops_CR_313063_matrix.csv"
# [1] 1998

# %%
head(paste0(rename_data$SampleID,'_ADT.csv'))
# Out:
# [1] "D0009_Rep1_ADT.csv" "D0009_Rep2_ADT.csv" "D0010_Rep1_ADT.csv"
# [4] "D0010_Rep2_ADT.csv" "D0011_Rep1_ADT.csv" "D0011_Rep2_ADT.csv"

# %%
file.rename(from = ADT_list,
            to = paste0(rename_data$SampleID,'_ADT.csv'))
# Out:
#    [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [15] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [29] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [43] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [57] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [71] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [85] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [99] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [113] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [127] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [141] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [155] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# ...

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_TCR_out/")

# %%
TCR_list = basename(list.files(".",recursive = F))
head(TCR_list)
# Out:
# [1] "BBH202401160012_N-T-X1_filtered_contig_annotations.csv"
# [2] "BBH202401160012_N-T-X2_filtered_contig_annotations.csv"
# [3] "BFG202407199019_N-T-X1_filtered_contig_annotations.csv"
# [4] "BFG202407199019_N-T-X2_filtered_contig_annotations.csv"
# [5] "BL202401170033_N-T-X1_filtered_contig_annotations.csv"
# [6] "BL202401170033_N-T-X2_filtered_contig_annotations.csv"

# %%
head(paste0(rename_data$SampleID,'_TCR.csv'))
# Out:
# [1] "D0009_Rep1_TCR.csv" "D0009_Rep2_TCR.csv" "D0010_Rep1_TCR.csv"
# [4] "D0010_Rep2_TCR.csv" "D0011_Rep1_TCR.csv" "D0011_Rep2_TCR.csv"

# %%
file.rename(from = TCR_list,
            to = paste0(rename_data$SampleID,'_TCR.csv'))
# Out:
#    [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [15] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [29] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [43] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [57] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [71] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [85] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [99] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [113] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [127] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [141] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [155] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# ...

# %%
setwd("/home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_BCR_out/")

# %%
BCR_list = basename(list.files(".",recursive = F))
head(BCR_list)
# Out:
# [1] "BBH202401160012_N-B-X1_filtered_contig_annotations.csv"
# [2] "BBH202401160012_N-B-X2_filtered_contig_annotations.csv"
# [3] "BFG202407199019_N-B-X1_filtered_contig_annotations.csv"
# [4] "BFG202407199019_N-B-X2_filtered_contig_annotations.csv"
# [5] "BL202401170033_N-B-X1_filtered_contig_annotations.csv"
# [6] "BL202401170033_N-B-X2_filtered_contig_annotations.csv"

# %%
head(paste0(rename_data$SampleID,'_BCR.csv'))
# Out:
# [1] "D0009_Rep1_BCR.csv" "D0009_Rep2_BCR.csv" "D0010_Rep1_BCR.csv"
# [4] "D0010_Rep2_BCR.csv" "D0011_Rep1_BCR.csv" "D0011_Rep2_BCR.csv"

# %%
file.rename(from = BCR_list,
            to = paste0(rename_data$SampleID,'_BCR.csv'))
# Out:
#    [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [15] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [29] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [43] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [57] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [71] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [85] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#   [99] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [113] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [127] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [141] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [155] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# ...

# %%
# Run in shell, remove the redundant files generated by emptydrop in celescope v2
# rm -rf /home/liyanguo/MyImmuCell/01_rawdata/Reference_Atlas_scRNA/*/GeneFull_Ex50pAS/filtered
