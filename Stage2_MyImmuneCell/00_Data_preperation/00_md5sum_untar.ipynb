# %% [markdown]
# # MD5 check in shell

# %% [markdown]
# ## MyImmuCell CITE-seq-RNA

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_scRNA

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 48 my_func

# %% [raw]
# All md5sum output is OK!

# %% [markdown]
# ## MyImmuCell CITE-seq-ADT

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_ADT

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 72 my_func

# %%
All md5sum output is OK!

# %% [markdown]
# ## MyImmuCell VDJ

# %%
#run in shell
#TCR
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_TCR

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 72 my_func

# %%
All md5sum output is OK!

# %%
#run in shell
#BCR
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_BCR

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 72 my_func

# %%
All md5sum output is OK!

# %% [markdown]
# ## MyImmuCell solo out

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_scRNA_solo_out

my_func() {
  md5sum -c $1
}
export -f my_func
ls *.md5 | parallel -j 16 my_func

# %%
All md5sum output is OK!

# %% [markdown]
# # Untar and copy in shell

# %% [markdown]
# ## MyImmuCell scRNA

# %%
#run in shell
cd /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_scRNA

for sample in `ls *.tar`
do
mkdir -p /home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_scRNA/$(basename $sample .tar)
tar -xvf $sample -C /home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_scRNA/$(basename $sample .tar)
rm -r /home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_scRNA/$(basename $sample .tar)/GeneFull_Ex50pAS/filtered
done

# %% [markdown]
# ## MyImmuCell ADT

# %%
#run in shell
cp -u /localdisk/immune/0_raw_immune1k/celescope_v2/MyImmuCell_ADT/*.csv /home/liyanguo/MyImmuCell/01_rawdata/MyImmuCell_ADT
