# %%
import os
import sys
import scipy
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import scipy.io as sio
import scanpy.external as sce
import matplotlib.pyplot as plt
import re
import anndata as ad
import statistics
import torch
import scvi
import tempfile
import sklearn
import mudata as md
md.set_options(pull_on_update=False)
import muon
from datetime import datetime
from scib_metrics.benchmark import Benchmarker
from sklearn_ann.kneighbors.annoy import AnnoyTransformer
from multiprocessing import Pool
import uuid
print("Last run with scvi-tools version:", scvi.__version__)
scvi.settings.num_threads = 48
scvi.settings.seed = 0
sc._settings.ScanpyConfig.n_jobs=48
sc.settings.verbosity = 4
sc.settings.set_figure_params(dpi=100, fontsize=10, dpi_save=400,
    facecolor = 'white', figsize=(8,8), format='png')
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
# Out:
# /home/liyanguo/anaconda3/envs/R/lib/python3.12/site-packages/docrep/decorators.py:43: SyntaxWarning: 'param_categorical_covariate_keys' is not a valid key!
#   doc = func(self, args[0].__doc__, *args[1:], **kwargs)
# /home/liyanguo/anaconda3/envs/R/lib/python3.12/site-packages/docrep/decorators.py:43: SyntaxWarning: 'param_continuous_covariate_keys' is not a valid key!
#   doc = func(self, args[0].__doc__, *args[1:], **kwargs)
# Seed set to 0
# Last run with scvi-tools version: 1.3.0

# %%
sc.logging.print_header()
# Out:
# scipy	1.15.2
# numpy	2.2.5
# pandas	2.2.3
# scanpy	1.11.1
# seaborn	0.13.2
# matplotlib	3.9.2
# anndata	0.11.4
# torch	2.4.1 (2.4.1+cu121)
# scvi-tools	1.3.0
# scikit-learn	1.5.2
# mudata	0.3.1
# muon	0.1.6
# scib-metrics	0.5.1
# sklearn-ann	0.1.2
# ----	----
# annoy	1.17.3
# jaxlib	0.4.33
# kiwisolver	1.4.7
# optree	0.12.1
# msgpack	1.1.0
# absl-py	2.1.0
# entrypoints	0.4
# platformdirs	4.3.7
# ml-dtypes	0.4.1
# sympy	1.13.3
# jupyter_core	5.7.2
# ml_collections	0.1.1
# packaging	24.2
# awkward_cpp	38
# typing_extensions	4.13.2
# numexpr	2.10.2
# contextlib2	21.6.0
# h5py	3.11.0 (3.13.0)
# pyro-ppl	1.9.1
# asciitree	0.3.3
# pytz	2024.1
# pyparsing	3.1.4
# tqdm	4.66.5
# mpmath	1.3.0
# jaraco.functools	4.0.1
# pure_eval	0.2.3 (0.2.2)
# opt-einsum	3.3.0 (v3.3.0)
# flax	0.9.0
# traitlets	5.14.3
# jaraco.collections	5.1.0
# docrep	0.3.2
# pure-eval	0.2.3 (0.2.2)
# threadpoolctl	3.5.0
# Cython	3.0.11
# Pygments	2.18.0 (2.15.1)
# attrs	24.2.0
# ipython	8.27.0
# etils	1.9.4
# prompt-toolkit	3.0.48
# awkward	2.6.8
# plottable	0.1.5
# pyzmq	26.2.0 (25.1.2)
# jedi	0.19.1
# psutil	6.0.0 (5.9.0)
# numba	0.61.2
# Jinja2	3.1.4
# filelock	3.16.1
# torchmetrics	1.4.2
# debugpy	1.6.7
# python-dateutil	2.9.0.post0
# jaraco.context	5.3.0
# pillow	10.4.0
# igraph	0.11.6
# optax	0.2.3
# charset-normalizer	3.3.2
# cloudpickle	3.1.1
# umap-learn	0.5.6
# statsmodels	0.14.3
# pycparser	2.22
# multipledispatch	1.0.0 (0.6.0)
# toolz	0.12.1
# fsspec	2024.9.0
# wcwidth	0.2.13 (0.2.5)
# chex	0.1.86
# executing	2.1.0 (0.8.3)
# natsort	8.4.0
# tornado	6.4.2
# parso	0.8.3
# numcodecs	0.14.1
# cffi	1.17.1
# setuptools	75.1.0
# numpyro	0.15.3
# rich	13.8.1
# dask	2025.4.0
# pynndescent	0.5.13
# decorator	5.1.1
# more-itertools	10.5.0
# llvmlite	0.44.0
# legacy-api-wrap	1.4
# lightning	2.5.1.post0
# six	1.16.0
# pyarrow	18.0.0
# ipykernel	6.29.5
# asttokens	3.0.0
# comm	0.2.1
# zarr	2.18.3
# sparse	0.15.4
# jupyter_client	7.4.9
# cycler	0.12.1
# jaraco.text	3.12.1
# texttable	1.7.0
# matplotlib-inline	0.1.6
# lightning-utilities	0.11.7
# prompt_toolkit	3.0.48
# xarray	2024.9.0
# triton	3.0.0
# ipywidgets	8.1.5
# leidenalg	0.10.2
# joblib	1.4.2
# defusedxml	0.7.1
# astunparse	1.6.3
# stack-data	0.6.3 (0.2.0)
# MarkupSafe	2.1.5
# PyYAML	6.0.2
# jax	0.4.33
# patsy	0.5.6
# session-info2	0.1.2
# ----	----
# Python	3.12.6 | packaged by conda-forge | (main, Sep 30 2024, 18:08:52) [GCC 13.3.0]
# OS	Linux-5.15.0-117-generic-x86_64-with-glibc2.31
# CPU	96 logical CPU cores, x86_64
# GPU	No GPU found
# Updated	2025-05-03 10:54

# %%
obj_path = '/home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/'
sc.settings.figdir = obj_path

# %%
#dataset = sys.argv[1] #high_nCount_RNA, low_nCount_RNA
dataset = "high_nCount_RNA"

# %%
adata = sc.read_h5ad(f"{obj_path}scRNA_MyImmuCell_{dataset}_HVG.h5ad")

# %% [markdown]
# # 1. Load latent representation

# %%
adata.obsm["X_TOTALVI"]=np.load(f"{obj_path}{dataset}_X_TOTALVI.npy")

# %%
# sc.pp.neighbors take about 60 minutes for 3000M cells
print(f"Do sc.pp.neighbors with AnnoyTransformer,{datetime.now()}")
sc.pp.neighbors(adata, transformer=AnnoyTransformer(20), use_rep='X_TOTALVI')

# %%
print(f"Run UMAP,{datetime.now()}")
sc.tl.umap(adata, min_dist=0.5)

# %%
def run_leiden_parallel(params):
    global adata
    key_added = f"L1_leiden_TOTALVI_{params['resolution']}"
    sc.tl.leiden(adata, key_added=f'L1_leiden_TOTALVI_{params['resolution']}', 
                 **params,
                 use_weights=True,directed=False,flavor="igraph")
    return {key_added: adata.obs[key_added]}

# %%
param = [
        {"resolution": 2},
        {"resolution": 3},
        {"resolution": 4},
]

# %%
with Pool(4) as p:
    leiden_columns = p.map(run_leiden_parallel, param)

# %%
for col_dict in leiden_columns:
    for key, values in col_dict.items():
        adata.obs[key] = values

# %%
del adata.obsp
del adata.layers

# %%
adata.write(f"{obj_path}scRNA_MyImmuCell_{dataset}_HVG.h5ad",compression="gzip")

# %%
leiden_data = adata.obs.loc[:,['L1_leiden_TOTALVI_2','L1_leiden_TOTALVI_3', 'L1_leiden_TOTALVI_4']]
obsm = adata.obsm
leiden_groups=['L1_leiden_TOTALVI_2','L1_leiden_TOTALVI_3', 'L1_leiden_TOTALVI_4']

# %% [markdown]
# # 2. Get all gene count data in backed mode

# %%
adata = sc.read_h5ad(f"{obj_path}scRNA_MyImmuCell_{dataset}_HVG.h5ad",backed='r')

# %%
adata_raw = sc.read_h5ad(f'/home/liyanguo/MyImmuCell/02_Read_QC/scRNA_MyImmuCell_{dataset}.h5ad',backed='r')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 30204462 × 2000 backed at '/home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/scRNA_MyImmuCell_high_nCount_RNA_HVG.h5ad'
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'SampleID', 'DonorID', 'percent_mito', 'percent_ribo', 'percent_mito_ribo', 'log10GenesPerUMI', 'percent_top50', 'percent_oxphos', 'percent_apop', 'percent_dna_repair', 'percent_ieg', 'percent_hemo', 'S.Score', 'G2M.Score', 'Phase', 'Reference_Atlas_L1L2_mv', 'Reference_Atlas_L1L2_pl', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'Immune_All_High', 'Immune_All_Low', 'Adult_Human_Blood', 'Adult_Human_Bone_marrow', 'percent.mt', 'predicted.celltype.l2.score', 'predicted.celltype.l2', 'predicted.celltype.l1.score', 'predicted.celltype.l1', 'mapping.score', 'scDblFinder.class', 'High_quality', 'L1_leiden_TOTALVI_2', 'L1_leiden_TOTALVI_3', 'L1_leiden_TOTALVI_4', 'L1_leiden_TOTALVI_5'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'L1_leiden_TOTALVI_2_colors', 'hvg', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_TOTALVI', 'X_umap'

# %%
adata_raw
# Out:
# AnnData object with n_obs × n_vars = 32707953 × 38606 backed at '/home/liyanguo/MyImmuCell/02_Read_QC/scRNA_MyImmuCell_high_nCount_RNA.h5ad'
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'SampleID', 'DonorID', 'percent_mito', 'percent_ribo', 'percent_mito_ribo', 'log10GenesPerUMI', 'percent_top50', 'percent_oxphos', 'percent_apop', 'percent_dna_repair', 'percent_ieg', 'percent_hemo', 'S.Score', 'G2M.Score', 'Phase', 'Reference_Atlas_L1L2_mv', 'Reference_Atlas_L1L2_pl', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'Immune_All_High', 'Immune_All_Low', 'Adult_Human_Blood', 'Adult_Human_Bone_marrow', 'percent.mt', 'predicted.celltype.l2.score', 'predicted.celltype.l2', 'predicted.celltype.l1.score', 'predicted.celltype.l1', 'mapping.score', 'scDblFinder.class'

# %% [markdown]
# # 3. Plot leiden umap

# %%
print(f"Plot umap,{datetime.now()}")
sc.pl.umap(
    adata,
    color=['L1_leiden_TOTALVI_3'],
    legend_fontsize=6,legend_loc='on data',ncols=3,frameon=False,
    save=f'_{dataset}_TOTALVI_L1_annoy_leiden',show=False
)
# Out:
# Plot umap,2025-05-03 18:57:47.515851
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/umap_high_nCount_RNA_TOTALVI_L1_annoy_leiden.png
# <Axes: title={'center': 'L1_leiden_TOTALVI_3'}, xlabel='UMAP1', ylabel='UMAP2'>

# %% [markdown]
# # 4. Plot canonical and reference atlas marker genes

# %%
marker_dict1={
    'Immune cell': ['PTPRC'],

    'Lineage':['CD7','CD3E',
               'IL7R',
               'SPON2','KLRF1',
               'CD79A','MS4A1',
               'CD14','FCGR3A',
               'CSF3R','FCGR3B'
              ],
    
    'HSPC':['CD34','SPINK2','CYTL1','PROM1','SMIM24','EGFL7',
            'SOX4','KIT', 'DNTT','ETV6','MCL1','STAT5A','CD48'],
    'Basophil':['HDC','GATA2', 'FCER1A', 'IL3RA','ENPP3','MS4A2','IL4'],
    'Eosinophil':['ALOX15','SIGLEC10','SIGLEC8','LMO4','EPX','ITGA1','CCR3',],
    'Mast cell':['FCER1A','MS4A2','KIT'],

    'CEACAM8- Neutrophil':['FCGR3B','CSF3R','MME','G0S2','MNDA',],
    'CEACAM8+ Neutrophil':['CEACAM8','LTF','BPI','MPO','ELANE'],
    
    'Classical monocytes' :['CD14','LYZ','VCAN','FCN1',],
    'Non-classical monocytes' :['FCGR3A','CDKN1C','TCF7L2','CSF1R',],
    'DC':['ENHO','CD1C','HLA-DQA1','FCER1A','CLEC10A','CLEC9A','FLT3'],
    'pDC':['CLEC4C','IL3RA'],
    
    'T naive': ['CD3D','CD3G','LEF1','IL7R','CCR7', 'TCF7','SELL','BACH2','ITGB1'],#ITGB1-
    'CD4+ T': ['CD4','MAL','RCAN3','IL6ST','TRAT1','CAMK4'],
    'TRAV1-2- CD8+ T': ['CD8A', 'CD8B','LINC02446','CCL5','GZMH','GZMK','ZNF683','THEMIS'],
    'γδ T':['TRDV2','TRGV9','TRDC','KLRG1','TRGC1','TRGC2','CCL5','CST7','TRDV1'],
    'MAIT':['SLC4A10','KLRB1','TRAV1-2','RORA','CXCR6'],
    'Treg':['FOXP3','CTLA4','IL2RA','TIGIT','RTKN2','STAM'],

    'NK': ['KLRD1','GNLY','PRF1','GZMB','CD244','CD247',
           'IL2RB','XCL1','XCL2'],
    'CD56dim':['FCGR3A','SPON2',],#CD16+
    'CD56bright':['IL7R','GZMK','NCAM1','GATA3'],#CD16-/low
    'Adaptive NK':['KLRC2','B3GAT1',],

    'Lymphocyte relate':['RUNX1','RUNX2','KLRF1','KLRC1',#KLRC1=NKG2AA抑制   NKp80=KLRF1
                         'KLRD1','KLRG1','EOMES',
                        'NCR2','NCR3','SYNE1'],#KLRD1=CD94抑制 KLRG1抑制

    'ILC': ['IL7R','LTB','RGS1','TNFSF10','PLCG2','RUNX1','TOX','FLT3'],#lin-
    'pILC':['NFIL3',],
    'ILC1':['IL2RB','TBX21','NCR1',],#CD56-
    'ILC2':['GATA3','IL2RA','PTGDR2','KLRG1','ZBTB16','RORA','MAF'],#lin- CD4-
    'ILC3-NCR+':['AHR','KIT','RORC','NCR1','NCR2','RUNX2',],#mature ILC #lin- CD56+ CD4-
    'LTi':['CCR7','KIT','ITGA4',],#mature ILC #lin- CD56-
    'ILCreg':['SOX4',],#KLRG1-
    
    'NKT':['TRAV24','TRBV28','CLDND1'], 
    'DN T':['FXYD2','NUCB2','MYB',],
    'T Develop':['SPI1','ZBTB7B','RUNX3'],
    'T activation': ['CD69', 'CD38'],

    'B naive': ['CD79A','TCL1A',],
    'Transitional B': ['MME','CD38','CD9','FCER2','EBF1','BACH2','PAX5', 'MSI2',],
    'Atypical memory B': ['TBX21','ITGAX','FCRL5','SIGLEC6','SOX5'],
    'Plasma':['JCHAIN','IGHA1','TNFRSF17','MZB1','CD38','XBP1', 'PRDM1'],
    'CD5+ B':['IGHV3-7','LEF1','CTLA4','CD5'],

    'Platelet':['PF4','PPBP','GP9','CAVIN2'],
    'RBC':['HBB','HBA2','BLVRB'],
    'Proliferative signal':['MKI67','TOP2A','STMN1'],
    'Other':['ITGAM','ANK3','PRKCA','BCL6','TGFB1','CXCR4','GATA1','ATXN1','SELPLG',
             'ITGA6','CSF1','CSF1R','CSF2','ETS1','CD44','IRF4','STAT3','BATF','TGFBR1','TGFBR2']
}
#Protein :       CD114,  CD116,  CD123, CD124, CD125,  CD126, CD203c,  KLRB1,  CD25,   CD29,   CD73,  CD127,  CD119,  CRTH2,  PLZF, CD62L, TdT, CD57,     ThpOK,   PU.1, CRTH2
#Gene Symbol :	CSF3R,   CSF2RA, IL3RA, IL4R,  IL5RA,  IL6R, ENPP3,   CD161,  IL2RA,  ITGB1,  NT5E,  IL7R,  IFNGR1,  PTGDR2, ZBTB16, SELL, DNTT, B3GAT1, ZBTB7B,   SPI1, PTGDR2

#Protein :    CD42a, CD42b, 
#Gene Symbol :GP9, GP1BA

#TCR : Vα7.2
#Gene : TRAV1-2

#GCSF=CSF3, for neutrophils
#GM-CSF=CSF2, granulocyte-macrophage colony-stimulating factor
#M-CSF=CSF1, macrophage colony-stimulating factor

# %%
marker_dict2={
    'B': ['MS4A1','CD79A','BANK1','CD22','FCRL1','TCL1A','FCER2'],
    'Plasma|Plasmablast':['TNFRSF17','JCHAIN','IGHA1','MZB1','XBP1'],
    
    'CD4+ T':['TCF7','MAL','IL7R','RCAN3','DGKA',],
    'CD8+ T':['CD8A','CD8B','LINC02446','CCL5','THEMIS','KLRK1'],
    'MAIT':['SLC4A10','TRAV1-2','KLRB1',],
    'Platelet':['TUBB1','CAVIN2','PF4',],
    'NKT':['TRAV24','TRBV28','CLDND1','DZIP3','ORM2','GPRC5D','FGFR2'],
    'NK': ['KLRF1', 'SPON2','GNLY', 'GZMB','PRF1','KLRD1','TYROBP'],
    'non-NK ILC': ['FSTL4', 'HPGDS','PKIB', 'PTGDR2','SCART1'],
    'γδ T':['TRDC','TRDV2','TRGC1','TRGC2','TRGV9','KLRD1','CCL5','KLRC1'],
    
    'HPSC':['CD34','NPR3','SMIM24','SPINK2','CRHBP','EMP1','ACY3','NYNRIN'], 
    'DC':['ENHO','CLEC10A','CD1C','FCER1A','FLT3','HLA-DQA1'],
    'Classical monocyte':['FCN1','VCAN','LRP1','CD14','MS4A6A','CST3'],
    'Non-classical monocyte':['CDKN1C','CSF1R','CKB','NEURL1','LYPD2','AIF1'],
    'CEACAM8+ Neutrophil':['CEACAM8','LCN2','BPI','LTF','CRISP3','CEACAM6'],
    'CEACAM8- Neutrophil':['CSF3R','NAMPT','FCGR3B','IFITM2','SLC25A37','FCGR3B', 'S100A9'],
    'Eosinophil':['EPX', 'SIGLEC8', 'IL5RA'],
    'Basophil':['HDC','GATA2','MS4A2','AKAP12','CLC','IL4','RHOXF1P1',], 
    'Mast':['STXBP6', 'PPIL6', 'KIT',],
    'pDC':['SERPINF1','PTPRS','LILRA4','TNFRSF21','PLD4','SCT'],
    
    'Proliferative signal':['MKI67','TOP2A','STMN1'],
}

# %%
all_items = []
for values in marker_dict1.values():
    all_items.extend(values)
dict1 = np.unique(np.array(all_items))

# %%
all_items = []
for values in marker_dict2.values():
    all_items.extend(values)
dict2 = np.unique(np.array(all_items))

# %%
marker_selected = np.unique(
    np.hstack((dict2,dict1))
)

# %%
len(marker_selected)
# Out:
# 237

# %% [markdown]
# ## Get marker_selected count data

# %%
adata_raw = adata_raw[adata.obs_names,adata_raw.var_names.isin(marker_selected)]

# %%
name = f"tmp_{dataset}_{str(uuid.uuid4())}.h5ad"
adata_raw.copy(f"/home/liyanguo/MyImmuCell/tmp/{name}")
# Out:
# AnnData object with n_obs × n_vars = 30204462 × 237 backed at '/home/liyanguo/MyImmuCell/tmp/tmp_high_nCount_RNA_a0170d8b-9f92-4930-8a5e-02fff3cdbd5e.h5ad'
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'SampleID', 'DonorID', 'percent_mito', 'percent_ribo', 'percent_mito_ribo', 'log10GenesPerUMI', 'percent_top50', 'percent_oxphos', 'percent_apop', 'percent_dna_repair', 'percent_ieg', 'percent_hemo', 'S.Score', 'G2M.Score', 'Phase', 'Reference_Atlas_L1L2_mv', 'Reference_Atlas_L1L2_pl', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'Immune_All_High', 'Immune_All_Low', 'Adult_Human_Blood', 'Adult_Human_Bone_marrow', 'percent.mt', 'predicted.celltype.l2.score', 'predicted.celltype.l2', 'predicted.celltype.l1.score', 'predicted.celltype.l1', 'mapping.score', 'scDblFinder.class'

# %%
adata_raw.file.close()

# %%
adata = sc.read(f"/home/liyanguo/MyImmuCell/tmp/{name}")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 30204462 × 237
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'SampleID', 'DonorID', 'percent_mito', 'percent_ribo', 'percent_mito_ribo', 'log10GenesPerUMI', 'percent_top50', 'percent_oxphos', 'percent_apop', 'percent_dna_repair', 'percent_ieg', 'percent_hemo', 'S.Score', 'G2M.Score', 'Phase', 'Reference_Atlas_L1L2_mv', 'Reference_Atlas_L1L2_pl', 'AIFI_L1', 'AIFI_L2', 'AIFI_L3', 'Immune_All_High', 'Immune_All_Low', 'Adult_Human_Blood', 'Adult_Human_Bone_marrow', 'percent.mt', 'predicted.celltype.l2.score', 'predicted.celltype.l2', 'predicted.celltype.l1.score', 'predicted.celltype.l1', 'mapping.score', 'scDblFinder.class'

# %%
adata.obs = adata.obs.join(leiden_data, how='left')

# %%
try:
    print(f"{adata.X.max()}")
except:
    print(adata.isbacked)
# Out:
# 3650.0

# %%
os.system(f"rm /home/liyanguo/MyImmuCell/tmp/{name}")
# Out:
# 0

# %% [markdown]
# ## normalize and plot

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:02)

# %%
for group in ['L1_leiden_TOTALVI_3']:
    sc.pl.dotplot(
        adata,
        groupby=group,
        save=f"{dataset}_{group}_marker",
        var_names=marker_dict1,
        standard_scale="var",
        dot_min=0.1,
        show=False
    )
# Out:
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/dotplot_high_nCount_RNA_L1_leiden_TOTALVI_3_marker.png

# %%
for group in ['L1_leiden_TOTALVI_3']:
    sc.pl.dotplot(
        adata,
        groupby=group,
        save=f"{dataset}_{group}_ref_markers",
        var_names=marker_dict2,
        standard_scale="var",
        dot_min=0.1,
        show=False
    )
# Out:
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/dotplot_high_nCount_RNA_L1_leiden_TOTALVI_3_ref_markers.png

# %% [markdown]
# # 5. Process and Plot adt

# %%
adt = sc.read_h5ad(f"{obj_path}scADT_MyImmuCell_{dataset}.h5ad")

# %%
adt
# Out:
# AnnData object with n_obs × n_vars = 30204462 × 30
#     obs: 'orig.ident', 'SampleID', 'DonorID', 'Batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'High_quality', 'doublets_by_markers', 'L1_leiden_TOTALVI_2', 'L1_leiden_TOTALVI_3', 'L1_leiden_TOTALVI_4'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     layers: 'clr', 'denoised_protein', 'dsb', 'protein_foreground_prob'

# %% [markdown]
# ## add adata obsm and leiden

# %%
adt.obs = adt.obs.join(leiden_data, how='left')

# %%
adt.obsm = obsm

# %% [markdown]
# ## add dsb

# %%
adt2 = sc.read_h5ad(f"/home/liyanguo/MyImmuCell/02_Read_QC/scADT_MyImmuCell_dsb_{dataset}.h5ad")

# %%
adt2 = adt2[adt.obs_names,:].copy()

# %%
adt.layers["dsb"] = adt2.layers["dsb"].copy()

# %%
del adt2

# %%
adt
# Out:
# AnnData object with n_obs × n_vars = 30204462 × 30
#     obs: 'orig.ident', 'SampleID', 'DonorID', 'Batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'High_quality', 'doublets_by_markers', 'L1_leiden_TOTALVI_2', 'L1_leiden_TOTALVI_3', 'L1_leiden_TOTALVI_4'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     obsm: 'X_TOTALVI', 'X_umap'
#     layers: 'clr', 'denoised_protein', 'dsb', 'protein_foreground_prob'

# %%
adt.X.max()
# Out:
# np.float32(2081.0)

# %%
adt.write(f"{obj_path}scADT_MyImmuCell_{dataset}.h5ad",compression="gzip")

# %% [markdown]
# ## plot

# %%
adt_dict={
    "CD45RA": ["CD45RA"],
    
    'B': ['IgD','IgM',"CD19",'CD27','CD137'],
    
    "ILC|NK|NKT|γδ T|": ["CD56","CD161",'CD16',],
    
    "T": ["CD3","CD4","CD8",'CD27','CD28','CD134','CD272'],
    "Naive/Memory T": ["CD45RA","CD127","CD62L",'CD197',],
    "Treg":['CD25','CD137','CD357',],
    "Th1|ILC":["CD183",'CD186','CD366'],
    "Th17|ILC":['CD161','CD196',],
    "Tfh|ILC|Effector":['CD185','CD278','CD279',],

    'DC':['CD11c','HLA-DR',"CD183",'CD197'],

    'Monocytes':['CD14','CD16'],
}

# %%
for group in ['L1_leiden_TOTALVI_3']:
    sc.pl.dotplot(
    adt,
    groupby=group,
    var_names=adt_dict,
    save=f"{dataset}_{group}_scADT_TOTALVI_L1_dsb",layer='dsb',
    expression_cutoff=2,
    standard_scale="group",
    dot_min=0.1,
    show=False,
    )
# Out:
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/dotplot_high_nCount_RNA_L1_leiden_TOTALVI_3_scADT_TOTALVI_L1_dsb.png

# %%
for group in ['L1_leiden_TOTALVI_3']:
    sc.pl.dotplot(
    adt,
    groupby=group,
    var_names=adt_dict,
    save=f"{dataset}_{group}_scADT_TOTALVI_L1_clr",layer='clr',
    expression_cutoff=1,
    standard_scale="group",
    dot_min=0.1,
    show=False,
    )
# Out:
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/dotplot_high_nCount_RNA_L1_leiden_TOTALVI_3_scADT_TOTALVI_L1_clr.png

# %%
for group in ['L1_leiden_TOTALVI_3']:
    sc.pl.dotplot(
    adt,
    groupby=group,
    var_names=adt_dict,
    save=f"{dataset}_{group}_scADT_TOTALVI_L1_denoised_protein",layer='denoised_protein',
    expression_cutoff=1,
    standard_scale="group",
    dot_min=0.1,
    show=False,
    )
# Out:
# WARNING: saving figure to file /home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/dotplot_high_nCount_RNA_L1_leiden_TOTALVI_3_scADT_TOTALVI_L1_denoised_protein.png

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.11.4
# matplotlib          3.9.2
# mudata              0.3.1
# muon                0.1.6
# numpy               2.2.5
# pandas              2.2.3
# scanpy              1.11.1
# scib_metrics        0.5.1
# scipy               1.15.2
# scvi                1.3.0
# seaborn             0.13.2
# session_info        1.0.0
# session_info2       NA
# sklearn             1.5.2
# sklearn_ann         NA
# torch               2.4.1+cu121
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# Cython                      3.0.11
# PIL                         10.4.0
# absl                        NA
# annoy                       NA
# anyio                       NA
# arrow                       1.3.0
# asciitree                   NA
# asttokens                   NA
# astunparse                  1.6.3
# attr                        24.2.0
# attrs                       24.2.0
# awkward                     2.6.8
# awkward_cpp                 NA
# babel                       2.17.0
# certifi                     2024.08.30
# cffi                        1.17.1
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.86
# cloudpickle                 3.1.1
# comm                        0.2.1
# contextlib2                 NA
# cycler                      0.12.1
# cython                      3.0.11
# cython_runtime              NA
# dask                        2025.4.0
# dateutil                    2.9.0.post0
# debugpy                     1.6.7
# decorator                   5.1.1
# defusedxml                  0.7.1
# distutils                   3.12.6
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.9.4
# executing                   0.8.3
# fastjsonschema              NA
# filelock                    3.16.1
# flax                        0.9.0
# fqdn                        NA
# fsspec                      2024.9.0
# h5py                        3.13.0
# idna                        3.10
# igraph                      0.11.6
# ipykernel                   6.29.5
# ipython_genutils            0.2.0
# ipywidgets                  8.1.5
# isoduration                 NA
# jaraco                      NA
# jax                         0.4.33
# jaxlib                      0.4.33
# jedi                        0.19.1
# jinja2                      3.1.4
# joblib                      1.4.2
# json5                       0.10.0
# jsonpointer                 3.0.0
# jsonschema                  4.23.0
# jsonschema_specifications   NA
# jupyter_events              0.12.0
# jupyter_server              2.15.0
# jupyterlab_server           2.27.3
# kiwisolver                  1.4.7
# legacy_api_wrap             NA
# leidenalg                   0.10.2
# lightning                   2.5.1.post0
# lightning_utilities         0.11.7
# llvmlite                    0.44.0
# markupsafe                  2.1.5
# matplotlib_inline           0.1.6
# ml_collections              NA
# ml_dtypes                   0.4.1
# more_itertools              10.5.0
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.1.0
# multipledispatch            0.6.0
# natsort                     8.4.0
# nbformat                    5.10.4
# numba                       0.61.2
# numcodecs                   0.14.1
# numexpr                     2.10.2
# numpyro                     0.15.3
# opt_einsum                  v3.3.0
# optax                       0.2.3
# optree                      0.12.1
# overrides                   NA
# packaging                   24.2
# parso                       0.8.3
# patsy                       0.5.6
# pkg_resources               NA
# platformdirs                4.3.7
# plottable                   0.1.5
# prometheus_client           NA
# prompt_toolkit              3.0.48
# psutil                      5.9.0
# pure_eval                   0.2.2
# pyarrow                     18.0.0
# pycparser                   2.22
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.15.1
# pynndescent                 0.5.13
# pyparsing                   3.1.4
# pyro                        1.9.1
# pythonjsonlogger            NA
# pytz                        2024.1
# referencing                 NA
# requests                    2.32.3
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# send2trash                  NA
# setuptools                  75.1.0
# six                         1.16.0
# sniffio                     1.3.1
# sparse                      0.15.4
# stack_data                  0.2.0
# statsmodels                 0.14.3
# sympy                       1.13.3
# texttable                   1.7.0
# threadpoolctl               3.5.0
# tlz                         0.12.1
# toolz                       0.12.1
# torchgen                    NA
# torchmetrics                1.4.2
# tornado                     6.4.2
# tqdm                        4.66.5
# traitlets                   5.14.3
# triton                      3.0.0
# typing_extensions           NA
# umap                        0.5.6
# uri_template                NA
# urllib3                     2.2.3
# wcwidth                     0.2.5
# webcolors                   NA
# websocket                   1.8.0
# xarray                      2024.9.0
# yaml                        6.0.2
# zarr                        2.18.3
# zmq                         25.1.2
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.27.0
# jupyter_client      7.4.9
# jupyter_core        5.7.2
# jupyterlab          4.3.5
# notebook            6.5.7
# -----
# Python 3.12.6 | packaged by conda-forge | (main, Sep 30 2024, 18:08:52) [GCC 13.3.0]
# Linux-5.15.0-117-generic-x86_64-with-glibc2.31
# -----
# Session information updated at 2025-05-03 20:46
# </pre>
# </details>
