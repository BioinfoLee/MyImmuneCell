# %%
import os
import sys
import scipy
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
from tqdm import tqdm
import uuid
import multiprocessing as mp
from multiprocessing import Pool
sc._settings.ScanpyConfig.n_jobs=24
sc.settings.verbosity = 1

# %%
sc.logging.print_header()
# Out:
# scipy	1.15.2
# numpy	2.2.5
# pandas	2.2.3
# scanpy	1.11.1
# anndata	0.11.4
# tqdm	4.66.5
# ----	----
# optree	0.12.1
# executing	2.1.0 (0.8.3)
# tornado	6.4.2
# pyparsing	3.1.4
# charset-normalizer	3.3.2
# astunparse	1.6.3
# h5py	3.11.0 (3.13.0)
# matplotlib	3.9.2
# more-itertools	10.5.0
# prompt_toolkit	3.0.48
# jaraco.context	5.3.0
# parso	0.8.3
# asttokens	3.0.0
# pure-eval	0.2.3 (0.2.2)
# PyYAML	6.0.2
# decorator	5.1.1
# cycler	0.12.1
# leidenalg	0.10.2
# pure_eval	0.2.3 (0.2.2)
# jaraco.collections	5.1.0
# entrypoints	0.4
# ipython	8.27.0
# MarkupSafe	2.1.5
# cffi	1.17.1
# defusedxml	0.7.1
# numba	0.61.2
# pytz	2024.1
# platformdirs	4.3.7
# comm	0.2.1
# setuptools	75.1.0
# igraph	0.11.6
# texttable	1.7.0
# natsort	8.4.0
# kiwisolver	1.4.7
# asciitree	0.3.3
# Jinja2	3.1.4
# jaraco.functools	4.0.1
# packaging	24.2
# dask	2025.4.0
# xarray	2024.9.0
# pyzmq	26.2.0 (25.1.2)
# scikit-learn	1.5.2
# joblib	1.4.2
# pyarrow	18.0.0
# jedi	0.19.1
# Pygments	2.18.0 (2.15.1)
# session-info2	0.1.2
# psutil	6.0.0 (5.9.0)
# legacy-api-wrap	1.4
# Cython	3.0.11
# pillow	10.4.0
# zarr	2.18.3
# python-dateutil	2.9.0.post0
# jupyter_core	5.7.2
# toolz	0.12.1
# awkward_cpp	38
# jupyter_client	7.4.9
# stack-data	0.6.3 (0.2.0)
# threadpoolctl	3.5.0
# traitlets	5.14.3
# sparse	0.15.4
# msgpack	1.1.0
# jaraco.text	3.12.1
# numexpr	2.10.2
# debugpy	1.6.7
# numcodecs	0.14.1
# prompt-toolkit	3.0.48
# fsspec	2024.9.0
# cloudpickle	3.1.1
# typing_extensions	4.13.2
# six	1.16.0
# ipykernel	6.29.5
# wcwidth	0.2.13 (0.2.5)
# torch	2.4.1 (2.4.1+cu121)
# llvmlite	0.44.0
# awkward	2.6.8
# ----	----
# Python	3.12.6 | packaged by conda-forge | (main, Sep 30 2024, 18:08:52) [GCC 13.3.0]
# OS	Linux-5.15.0-117-generic-x86_64-with-glibc2.31
# CPU	96 logical CPU cores, x86_64
# GPU	No GPU found
# Updated	2025-05-21 10:37

# %% [markdown]
# ## make_anndata, make_anndata_withoutBCR, make_anndata_withoutTCR

# %%
def make_anndata(celltype):
    global adata_raw
    global adt
    global obj_path
    indices = pd.read_csv(f'{obj_path}{celltype}/R4_indices_{celltype}.csv',index_col=0)
    if len(indices.index)>2000:
        adata = adata_raw[indices.index].to_memory()
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        sc.pp.highly_variable_genes(adata,flavor='seurat_v3',n_top_genes=2000,layer="counts",
                                subset=True)
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")
    else:
        adata = adata_raw[indices.index].to_memory()
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        adata.var['highly_variable']=True
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")

# %%
def make_anndata_withoutBCR(celltype):
    global adata_raw
    global adt
    global obj_path
    indices = pd.read_csv(f'{obj_path}{celltype}/R4_indices_{celltype}.csv',index_col=0)
    if len(indices.index)>2000:
        adata = adata_raw[indices.index]
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        sc.pp.highly_variable_genes(adata,flavor='seurat_v3',n_top_genes=2000,layer="counts",
                                subset=True)

        #Generate new highly_variable assignments except BCR
        bcr = pd.read_table('BCR_gene.txt',header=None)
        for i in range(1,len(bcr.values)):
            ind = adata.var_names.isin(bcr.values[i])
            adata.var.loc[ind,'highly_variable'] = False
        adata = adata[:, adata.var['highly_variable']].copy()
    
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")
    else:
        adata = adata_raw[indices.index]
        
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        adata.var['highly_variable']=True
        #Generate new highly_variable assignments except BCR
        bcr = pd.read_table('BCR_gene.txt',header=None)
        for i in range(1,len(bcr.values)):
            ind = adata.var_names.isin(bcr.values[i])
            adata.var.loc[ind,'highly_variable'] = False
        adata = adata[:, adata.var['highly_variable']].copy()
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")

# %%
def make_anndata_withoutTCR(celltype):
    global adata_raw
    global adt
    global obj_path
    indices = pd.read_csv(f'{obj_path}{celltype}/R4_indices_{celltype}.csv',index_col=0)
    if len(indices.index)>2000:
        adata = adata_raw[indices.index].to_memory()
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        sc.pp.normalize_total(adata, target_sum=1e4)
        sc.pp.log1p(adata)
        sc.pp.highly_variable_genes(adata,flavor='seurat_v3',n_top_genes=2000,layer="counts",
                                subset=True)

        #Generate new highly_variable assignments except TCR
        tcr = pd.read_table('TCR_gene.txt',header=None)
        for i in range(1,len(tcr.values)):
            ind = adata.var_names.isin(tcr.values[i])
            adata.var.loc[ind,'highly_variable'] = False
        adata = adata[:, adata.var['highly_variable']].copy()

    
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")
    else:
        adata = adata_raw[indices.index].to_memory()
        ##　Save scRNA count
        adata.write(f"{obj_path}{celltype}/{celltype}_count_scRNA.h5ad",compression="gzip")
        
        adata.layers["counts"] = adata.X.copy()
        adata.var['highly_variable']=True
        #Generate new highly_variable assignments except TCR
        tcr = pd.read_table('TCR_gene.txt',header=None)
        for i in range(1,len(tcr.values)):
            ind = adata.var_names.isin(tcr.values[i])
            adata.var.loc[ind,'highly_variable'] = False
        adata = adata[:, adata.var['highly_variable']].copy()
        ##　Save scRNA for TOTALVI
        adata.write(f"{obj_path}{celltype}/{celltype}_preprocess_scRNA.h5ad",compression="gzip")
        
        
        ##　Save scADT for TOTALVI
        adt_sub = adt[indices.index].copy()
        adt_sub.write(f"{obj_path}{celltype}/{celltype}_preprocess_scADT.h5ad",compression="gzip")

        print(f"{celltype},{adt_sub.n_obs},{len(adata.var['highly_variable'])} Done!")

# %% [markdown]
# # 1. Got HVG and TOTALVI data for L1 refine-high_nCount_RNA

# %%
dataset = "high_nCount_RNA"

# %%
obj_path = f'/home/liyanguo/MyImmuCell/05_MyImmuCell_subpopulation/Level2_Refine_R4/'

# %%
#Read in to 1000Gb memory
# if we add backed='r', use adata = adata_raw[indices.index].to_memory(), to process few cell data

adata_raw = sc.read_h5ad(f'/home/liyanguo/MyImmuCell/02_Read_QC/scRNA_MyImmuCell_{dataset}.h5ad',backed='r')

# %%
adt = sc.read_h5ad(f'/home/liyanguo/MyImmuCell/04_MyImmuCell_TOTALVI/scADT_MyImmuCell_{dataset}.h5ad')

# %% [markdown]
# # Remove BCR

# %%
celltypes=[
           'AtypicalB',
          ]

# %%
for i in celltypes:
    make_anndata_withoutBCR(i)
# Out:
# /tmp/ipykernel_532082/3956369833.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# AtypicalB,64155,1826 Done!

# %% [markdown]
# ## Normal process

# %%
celltypes=[
           'MAIT','gdT',
          ]

# %%
celltypes=['gdT',
          ]

# %%
for i in celltypes:
    make_anndata(i)
# Out:
# gdT,955599,2000 Done!

# %% [markdown]
# ## Remove TCR

# %%
celltypes=['CytotoxicCD4',
           'CD4_helper_memory',
           'TregCD4',
           'TregCD8'

           'NaiveCD8',
           'CD8Tcm',
           'TemCD8',
           'ProliferativeT'
          ]

# %%
celltypes=['CytotoxicCD4',
           'CD4_helper_memory',
           
           'NaiveCD8',
           'CD8Tcm',
           'TemCD8',
           'ProliferativeT'
          ]

# %%
for i in celltypes:
    make_anndata_withoutTCR(i)
# Out:
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# CytotoxicCD4,1008739,1895 Done!
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# CD4_helper_memory,2062161,1890 Done!
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# NaiveCD8,1252840,1890 Done!
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# CD8Tcm,146564,1898 Done!
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# TemCD8,3813199,1892 Done!
# /tmp/ipykernel_1362588/2312788742.py:11: ImplicitModificationWarning: Setting element `.layers['counts']` of view, initializing view as actual.
#   adata.layers["counts"] = adata.X.copy()
# ProliferativeT,32796,1892 Done!

# %%
celltypes=[
           'TregCD4',
          ]

# %%
for i in celltypes:
    make_anndata_withoutTCR(i)
# Out:
# TregCD4,788357,1895 Done!

# %% [raw]
# #传过去
# celltype='TregCD4'
# scp -P 6768 -r /home/liyanguo/MyImmuCell/05_MyImmuCell_subpopulation/Level2_Refine_R4/$celltype/ liyanguo@10.64.0.240:/home/liyanguo/MyImmuCell/05_MyImmuCell_subpopulation/Level2_Refine_R4/ &

# %% [raw]
# #传回来
# celltype='TemCD8'
# scp -r /home/liyanguo/MyImmuCell/05_MyImmuCell_subpopulation/Level2_Refine_R4/$celltype/* liyanguo@10.13.150.202:/home/liyanguo/MyImmuCell/05_MyImmuCell_subpopulation/Level2_Refine_R4/$celltype &
