# %% [markdown]
# ### author by yangshichen
# ### 注意：脚本仅供参考，使用前请仔细阅读

# %% [markdown]
# ### Python

# %%
import os

# %%
smr = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/Script_HPC/software_gaoyue/SMR/smr-1.3.1-linux-x86_64/smr-1.3.1'
opera = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/Script_HPC/genetics_software/opera_Linux'
bim = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/Genetics/10.maf01'
plotting_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/'
GWAS_dir_BBJ1 = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/GWAS_ma/ma_file_for_SMR_BBJ-1/'
GWAS_dir_BBJ2 = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/GWAS_ma/ma_file_for_SMR_BBJ-2/'
GWAS_dir_TPMI = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/GWAS_ma/opera_file_for_SMR_TPMI/'
eQTL_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_eQTL_besd/besd/'
pQTL_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_pQTL_besd/besd/'

# %% [markdown]
# ### Disease

# %%
celltype = 'Core_NDNs'
trait = 'Gastric_cancer' 
SMR_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_GWAS_SMR/'
processed_gwas_file = f"{SMR_output_dir}{trait}/{trait}_processed.ma"
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'ABO'
gi = f'"{opera}" --besd-flist "/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/xQTL_list_for_opera/Core_NDNs" --bfile "{bim}" --gwas-summary "{processed_gwas_file}" --beqtl-summary "{eQTL}" --out "{plotting_dir}myplot_{celltype}_{trait}_OPERA" --plot --probe "{probe}" --probe-wind 500 --gene-list "{plotting_dir}glist-hg38_strand" --diff-freq-prop 0.5'
os.system(gi)
# Out:
# *******************************************************************
# * Omics pleiotropic association (OPERA)
# * version 1.18
# * (C) 2022 Yang Wu, Jian Zeng and Jian Yang
# * The University of Queensland
# * MIT License
# *******************************************************************
# Analysis started: 14:58:26,Tue Mar 24,2026
#
# Options:
# --besd-flist /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/xQTL_list_for_opera/Core_NDNs
# --bfile /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/Genetics/10.maf01
# --gwas-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_GWAS_SMR/Gastric_cancer/Gastric_cancer_processed.ma
# --beqtl-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_eQTL_besd/besd/Core_NDNs
# --out /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/myplot_Core_NDNs_Gastric_cancer_OPERA
# --plot
# --probe ABO
# --probe-wind 500 Kb
# ...

# %%
celltype = 'Core_NDNs'
trait = 'Gastric_cancer' 
SMR_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_GWAS_SMR/'
processed_gwas_file = f"{SMR_output_dir}{trait}/{trait}_processed.ma"
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'ABO'
gi = f'"{smr}" --bfile "{bim}" --gwas-summary "{processed_gwas_file}" --beqtl-summary "{eQTL}" --out "{plotting_dir}myplot_{celltype}_{trait}_SMR" --plot --probe "{probe}" --probe-wind 500 --gene-list "{plotting_dir}glist-hg38_strand" --diff-freq-prop 0.5'
os.system(gi)
# Out:
# *******************************************************************
# * Summary-data-based Mendelian Randomization (SMR)
# * Version 1.3.1
# * Build at Sep 21 2022 12:13:19, by GCC 8.3
# * (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
# * The University of Queensland
# * MIT License
# *******************************************************************
# Analysis started: 15:0:33,Tue Mar 24,2026
#
# Options:
# --bfile /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/Genetics/10.maf01
# --gwas-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_GWAS_SMR/Gastric_cancer/Gastric_cancer_processed.ma
# --beqtl-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_eQTL_besd/besd/Core_NDNs
# --out /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/myplot_Core_NDNs_Gastric_cancer_SMR
# --plot
# --probe ABO
# --probe-wind 500 Kb
# --gene-list /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/glist-hg38_strand
# ...

# %% [markdown]
# ### Protein

# %%
celltype = 'Naïve_CD4_T_cells'
trait = 'urokinase_type_plasminogen_activator_measurement' 
SMR_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_pQTL_SMR/'
processed_gwas_file = f"{SMR_output_dir}{trait}/{trait}_processed.ma"
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'ABO'
gi = f'"{opera}" --besd-flist "/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/xQTL_list_for_opera/Naïve_CD4_T_cells" --bfile "{bim}" --gwas-summary "{processed_gwas_file}" --beqtl-summary "{eQTL}" --out "{plotting_dir}myplot_{celltype}_{trait}_OPERA" --plot --probe "{probe}" --probe-wind 500 --gene-list "{plotting_dir}glist-hg38_strand" --diff-freq-prop 0.5'
os.system(gi)
# Out:
# *******************************************************************
# * Omics pleiotropic association (OPERA)
# * version 1.18
# * (C) 2022 Yang Wu, Jian Zeng and Jian Yang
# * The University of Queensland
# * MIT License
# *******************************************************************
# Analysis started: 15:13:39,Tue Mar 24,2026
#
# Options:
# --besd-flist /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/xQTL_list_for_opera/Naïve_CD4_T_cells
# --bfile /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/Genetics/10.maf01
# --gwas-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_pQTL_SMR/urokinase_type_plasminogen_activator_measurement/urokinase_type_plasminogen_activator_measurement_processed.ma
# --beqtl-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_eQTL_besd/besd/Naïve_CD4_T_cells
# ...

# %%
celltype = 'Naïve_CD4_T_cells'
trait = 'urokinase_type_plasminogen_activator_measurement' 
SMR_output_dir = '/media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_pQTL_SMR/'
processed_gwas_file = f"{SMR_output_dir}{trait}/{trait}_processed.ma"
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'ABO'
gi = f'"{smr}" --bfile "{bim}" --gwas-summary "{processed_gwas_file}" --beqtl-summary "{eQTL}" --out "{plotting_dir}myplot_{celltype}_{trait}_SMR" --plot --probe "{probe}" --probe-wind 500 --gene-list "{plotting_dir}glist-hg38_strand" --diff-freq-prop 0.5'
os.system(gi)
# Out:
# *******************************************************************
# * Summary-data-based Mendelian Randomization (SMR)
# * Version 1.3.1
# * Build at Sep 21 2022 12:13:19, by GCC 8.3
# * (C) 2015 Futao Zhang, Zhihong Zhu and Jian Yang
# * The University of Queensland
# * MIT License
# *******************************************************************
# Analysis started: 15:15:53,Tue Mar 24,2026
#
# Options:
# --bfile /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/Genetics/10.maf01
# --gwas-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/eQTL_pQTL_SMR/urokinase_type_plasminogen_activator_measurement/urokinase_type_plasminogen_activator_measurement_processed.ma
# --beqtl-summary /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Data/SMR_eQTL_besd/besd/Naïve_CD4_T_cells
# --out /media/AnalysisDisk2/Yangshichen/2_My-Onek/WGS/Result/plot/SMR/plot/myplot_Naïve_CD4_T_cells_urokinase_type_plasminogen_activator_measurement_SMR
# --plot
# --probe ABO
# --probe-wind 500 Kb
# ...
