# %%
import os

# %%
smr = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/Script_HPC/software_gaoyue/SMR/smr-1.3.1-linux-x86_64/smr-1.3.1'
opera = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/Script_HPC/genetics_software/opera_Linux'
bim = '/media/scPBMC2_AnalysisFastDisk1/Huangzhuoli/genetics/qc/10.maf01'
plotting_dir = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Result/plot/SMR_OPERA_plot/'
GWAS_dir_lime = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Data/inhouse_GWAS_for_SMR_OPERA/'
GWAS_dir_pQTL = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Data/pQTL_ma/'
GWAS_dir_BBJ = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Data/BBJ_GWAS_for_SMR_OPERA/ma_file/'
eQTL_output_dir = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Data/SMR_eQTL_besd/besd/'
caQTL_output_dir = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Data/SMR_caQTL_besd/besd/'
xQTL_list_dir = '/media/scPBMC1_AnalysisDisk1/huangzhuoli/CIMA_r1/Result/plot/SMR_OPERA_plot/xQTL_list_for_opera/'

# %% [markdown]
# # 画As_IL12B和IKZF4

# %%
celltype = 'CD4_Treg_FOXP3'
trait = 'As'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF4'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Treg_FOXP3'
trait = 'As'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF4'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Treg_FOXP3'
trait = 'level_of_interleukin_12_subunit_beta_in_blood'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF4'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Treg_FOXP3'
trait = 'level_of_interleukin_12_subunit_beta_in_blood'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF4'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画chr6_167125409 和 CCR6

# %%
celltype = 'cDC2_CD1C'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cDC2_CD1C'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Transitional_B_SOX4'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Transitional_B_SOX4'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Bn_TCL1A'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Bn_TCL1A'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'CCR6'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画PADI2

# %%
celltype = 'cMono_CD14'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'PADI2'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 1000 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_CD14'
trait = 'RA'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'PADI2'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画TLR1

# %%
celltype = 'CD4_Tfh-like_CXCR5'
trait = 'macrophage_inflammatory_protein_1a_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TLR1'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Tfh-like_CXCR5'
trait = 'macrophage_inflammatory_protein_1a_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TLR1'
#ORMDL3
gi = f'{smr}  --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画S100A12

# %%
celltype = 'cMono_CD14'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_CD14'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{smr}  --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_IL1B'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_IL1B'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{smr}  --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Tn_CCR7'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_IFI44L'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Tn_CCR7'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{smr}  --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Bn_TCL1A'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Bn_TCL1A'
trait = 'protein_S100_A12_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'S100A12'
#ORMDL3
gi = f'{smr}  --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma  --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画TMEM258

# %%
celltype = 'CD4_Tfh-like_CXCR5'
trait = 'LPC_20_4'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TMEM258'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_lime}lipid_505.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Tfh-like_CXCR5'
trait = 'LPC_20_4'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TMEM258'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_lime}lipid_505.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_smr --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD8_CTL_GZMB'
trait = 'stem_Cell_Factor_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD8_CTL_GZMB'
trait = 'stem_Cell_Factor_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_smr --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD8_CTL_GZMB'
trait = 'TNF_related_apoptosis_inducing_ligand_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD8_CTL_GZMB'
trait = 'TNF_related_apoptosis_inducing_ligand_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_smr --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画糖尿病

# %%
celltype = 'CD4_Tn_CCR7'
trait = 'T2D'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'SLC16A11'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'CD4_Tn_CCR7'
trait = 'T2D'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'SLC16A11'
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_BBJ}hum0197.v3.BBJ.{trait}.v1.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %% [markdown]
# # 画NAAA

# %%
celltype = 'ncMono_FCGR3A'
trait = 'C_X_C_motif_chemokine_10_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'NAAA'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'ncMono_FCGR3A'
trait = 'C_X_C_motif_chemokine_10_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'NAAA'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Switched_Bm_IGHDneg'
trait = 'oncostatin_M_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF3'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'Switched_Bm_IGHDneg'
trait = 'oncostatin_M_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'IKZF3'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
# 画HEMGN

# %%
celltype = 'MK_GP9'
trait = 'C_X_C_motif_chemokine_5_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'HEMGN'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'MK_GP9'
trait = 'C_X_C_motif_chemokine_5_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'HEMGN'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
#画

# %%
celltype = 'cMono_CD14'
trait = 'TNF_related_activation_induced_cytokine_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TMEM199'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'cMono_CD14'
trait = 'TNF_related_activation_induced_cytokine_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'TMEM199'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'NKT_NCR1'
trait = 'TNF_related_apoptosis_inducing_ligand_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{opera} --besd-flist {xQTL_list_dir}{celltype} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_OPERA --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)

# %%
celltype = 'NKT_NCR1'
trait = 'TNF_related_apoptosis_inducing_ligand_measurement'
eQTL = f'{eQTL_output_dir}{celltype}'
probe = 'FADS2'
#ORMDL3
gi = f'{smr} --bfile {bim} --gwas-summary {GWAS_dir_pQTL}{trait}.ma --beqtl-summary {eQTL} --out {plotting_dir}myplot_{celltype}_{trait}_SMR --plot --probe {probe} --probe-wind 500 --diff-freq-prop 0.5 --gene-list {plotting_dir}glist-hg38_strand'
os.system(gi)
